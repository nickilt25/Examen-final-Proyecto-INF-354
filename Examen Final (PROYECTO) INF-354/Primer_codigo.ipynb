# %%
import os
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
#cambiar el directorio de trabajo actual
os.chdir('/content/drive/MyDrive/datos')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.tree  import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, accuracy_score
from imblearn.over_sampling import RandomOverSampler

# %%
data=pd.read_csv('WineQT.csv')
data = data_clean(data)

# %%
def data_clean(dataframe):
    # Categorizar niveles de alcohol
    bins = [0, 10, 12, float('inf')]  # Ejemplo: bajos (<10), medios (10-12), altos (>12)
    labels = [1, 2, 3]

    df = (dataframe
          .drop_duplicates()  # Eliminar duplicados
          .assign(alcohol_bins=dataframe['alcohol'].pipe(pd.cut, bins=bins, labels=labels))  # Agregar categorías de alcohol
          .reset_index(drop=True)
          .astype({
              'fixed acidity': 'float32',
              'volatile acidity': 'float32',
              'citric acid': 'float32',
              'residual sugar': 'float32',
              'chlorides': 'float32',
              'free sulfur dioxide': 'uint8',
              'total sulfur dioxide': 'uint16',
              'density': 'float32',
              'pH': 'float32',
              'sulphates': 'float32',
              'alcohol': 'float32',
              'quality': 'uint8',
              'alcohol_bins': 'uint8'  # Nueva columna categórica
          }))
    return df

# %% [markdown]
# PREPROCESAMIENTO

# %%
# df.shape
print(f"Num rows: {len(data)}")
print(f"Num columns: {len(data.columns)}")
# Out:
# Num rows: 1143
# Num columns: 14

# %%
# Imprimir valores únicos para cada columna
for column in data.columns:
    unique_values = data[column].unique()
    print("Unique values for column", column, ":")
    print(unique_values)
    print()
# Out:
# Unique values for column fixed acidity :
# [ 7.4  7.8 11.2  7.9  7.3  6.7  5.6  8.5  7.6  6.9  6.3  7.1  8.3  5.2
#   8.1  8.8  7.5  4.6  7.7  6.6  8.6 10.2  7.   7.2  8.   6.8  6.2  9.3
#   5.   8.4 10.1  9.4  8.2  5.8  9.2  8.9  6.4 11.5  9.6 12.8  9.7  8.7
#  12.  15.  10.8 11.1 10.  12.5 10.3 11.4  9.9 11.6 10.4 13.3 10.6  9.
#   9.8 13.4 11.9 10.9 13.8  9.1 13.5  6.1 10.5 12.6 13.7  9.5 12.2 12.3
#  15.6  5.3 11.3 13.   6.5 10.7 12.9 14.3 12.4 15.5 12.7 13.2 15.9  5.1
#  11.8  4.9  5.9 11.7  5.4  5.7  6. ]
#
# Unique values for column volatile acidity :
# [0.7   0.88  0.76  0.28  0.66  0.6   0.65  0.58  0.615 0.61  0.32  0.39
#  0.43  0.49  0.4   0.41  0.71  0.645 0.675 0.655 0.38  0.45  0.52  0.935
#  0.5   0.51  0.42  0.59  0.69  0.735 0.725 0.705 0.785 0.75  0.625 0.3
#  0.55  0.62  1.02  0.775 0.9   0.545 0.575 0.63  0.56  0.31  0.54  1.07
#  0.695 1.33  0.745 1.04  0.415 0.34  0.67  0.68  0.33  0.95  0.53  0.64
#  0.885 0.805 0.73  0.37  1.09  0.44  0.57  0.48  1.    0.635 0.21  0.35
#  0.975 0.87  0.18  0.26  0.27  0.36  0.83  0.46  0.47  0.77  0.795 0.665
#  0.24  0.85  0.765 0.84  0.96  0.78  0.685 0.23  0.315 0.82  0.29  0.25
#  0.22  0.825 0.715 0.595 0.585 0.835 0.845 0.8   0.98  0.92  1.035 1.025
#  0.565 0.74  0.72  0.865 0.875 0.965 0.91  0.89  0.12  0.86  0.295 1.005
#  10.4      11.5      11.4      12.4      11.       12.2      12.8
#  12.6      10.6      11.7      12.5      12.       11.9       8.7
#  13.3      12.9      12.3      11.2      11.1      13.4      11.3
#  11.6      12.1      11.8       8.4      12.7      14.9      13.2
#  13.6      10.033334  9.55      8.5      11.066667  8.8      13.566667
#  11.95      9.95      9.233334  9.25     10.55    ]
#
# Unique values for column quality :
# [5 6 7 4 8 3]
#
# Unique values for column Id :
# [   0    1    2 ... 1594 1595 1597]
#
# Unique values for column alcohol_bins :
# [1 2 3]

# %%
# Función para mostrar el conteo de valores por columna
def v_counts(dataframe):
    for i in dataframe:
        print(dataframe[i].value_counts())
        print("_____________________________________________________________________________")
v_counts(data)
# Out:
# fixed acidity
# 7.2     43
# 7.1     41
# 7.0     40
# 7.8     40
# 7.5     37
#         ..
# 4.6      1
# 13.7     1
# 13.4     1
# 13.5     1
# 12.2     1
# Name: count, Length: 91, dtype: int64
# _____________________________________________________________________________
# volatile acidity
# 0.600    32
# 0.500    32
# 0.430    31
# 0.390    29
# 0.580    28
#          ..
# 1.035     1
# 0.565     1
# 0.865     1
# 0.965     1
# 0.160     1
# Name: count, Length: 135, dtype: int64
# _____________________________________________________________________________
# citric acid
# 0.00    99
# 0.49    47
# 0.24    42
# 0.02    35
# 0.01    26
#         ..
# 0.61     1
# 0.72     1
# 1.00     1
# 0.75     1
# 0.62     1
# Name: count, Length: 77, dtype: int64
# _____________________________________________________________________________
# residual sugar
# 2.00    107
# 2.10    103
# 1.80     92
# 2.20     88
# 1.90     80
#        ...
# 7.30      1
# 7.20      1
# 2.95      1
# 3.65      1
# 4.40      1
# Name: count, Length: 80, dtype: int64
# _____________________________________________________________________________
# chlorides
# 0.080    48
# 0.077    41
# 0.074    38
# 0.084    38
# 0.078    36
#          ..
# 0.222     1
# 0.422     1
# 0.034     1
# 0.387     1
# 0.230     1
# Name: count, Length: 131, dtype: int64
# _____________________________________________________________________________
# free sulfur dioxide
# 6     99
# 5     80
# 12    58
# 10    52
# 15    51
# 7     51
# 9     48
# 16    47
# 8     45
# 17    40
# 11    39
# 13    39
# 14    38
# 18    37
# 3     33
# 19    32
# 4     31
# 21    30
# 23    23
# 27    21
# 24    21
# 26    21
# 25    20
# 20    18
# 32    18
# 31    16
# 28    15
# 29    14
# 34    12
# 22    12
# 30    10
# 36     9
# 35     9
# 33     8
# 38     8
# 41     5
# 40     4
# 48     4
# 42     3
# 37     3
# 1      3
# 45     2
# 52     2
# 51     2
# 43     2
# 68     2
# 39     2
# 46     1
# 53     1
# 55     1
# 66     1
# Name: count, dtype: int64
# _____________________________________________________________________________
# total sulfur dioxide
# 28     36
# 15     28
# 20     27
# 14     27
# 18     26
#        ..
# 129     1
# 135     1
# 103     1
# 165     1
# 111     1
# Name: count, Length: 137, dtype: int64
# _____________________________________________________________________________
# density
# 0.99760    27
# 0.99720    25
# 0.99680    22
# 0.99940    22
# 0.99640    21
#            ..
# 0.99438     1
# 0.99634     1
# 0.99426     1
# 0.99747     1
# 0.99651     1
# Name: count, Length: 388, dtype: int64
# _____________________________________________________________________________
# pH
# 3.30    41
# 3.36    40
# 3.38    38
# 3.39    37
# 3.26    33
#         ..
# 2.86     1
# 2.95     1
# 2.74     1
# 3.75     1
# 2.90     1
# Name: count, Length: 87, dtype: int64
# _____________________________________________________________________________
# sulphates
# 0.60    53
# 0.62    50
# 0.56    47
# 0.54    46
# 0.57    42
#         ..
# 1.61     1
# 1.31     1
# 0.33     1
# 1.56     1
# 1.01     1
# Name: count, Length: 89, dtype: int64
# _____________________________________________________________________________
# alcohol
# 9.500000     92
# 9.400000     72
# 9.800000     57
# 9.200000     50
# 10.000000    49
#              ..
# 11.950000     1
# 9.950000      1
# 9.233334      1
# 9.250000      1
# 10.550000     1
# Name: count, Length: 61, dtype: int64
# _____________________________________________________________________________
# quality
# 5    483
# 6    462
# 7    143
# 4     33
# 8     16
# 3      6
# Name: count, dtype: int64
# _____________________________________________________________________________
# Id
# 0       1
# 1079    1
# 1087    1
# 1086    1
# 1085    1
#        ..
# 543     1
# 544     1
# 545     1
# 546     1
# 1597    1
# Name: count, Length: 1143, dtype: int64
# _____________________________________________________________________________
# alcohol_bins
# 1    534
# 2    506
# 3    103
# Name: count, dtype: int64
# _____________________________________________________________________________

# %% [markdown]
# VERIFICACION DE DATOS NULOS

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# alcohol_bins            0
# dtype: int64

# %% [markdown]
# Como podemos ver no existen valores nulos dentro de los campos

# %% [markdown]
# VERIFICACION DE DATOS DUPLICADOS

# %%
print("Duplicados:", data.duplicated().sum())
# Out:
# Duplicados: 0

# %%
data.drop_duplicates(inplace=True)

# %%
print("Duplicados después de limpieza:", data.duplicated().sum())
# Out:
# Duplicados después de limpieza: 0

# %% [markdown]
# CLASIFICADOR
#
# Para este seccion hemos seleccionaod el calsificador de arbol de desicion
#
# Para este proceso lo que primero vamos a hacer es Scalar las caracteristicas(X) y separar el objetivo (Y)

# %%
# Separación de características (X) y objetivo (y)
X = data.drop(['quality'], axis=1)  # Usamos 'quality' como objetivo
y = data['quality']

# Balanceo de datos con RandomOverSampler
oversampler = RandomOverSampler()
X_resampled, y_resampled = oversampler.fit_resample(X, y)

# %%
scaler = StandardScaler()
scaler.fit(X)
# Out:
# StandardScaler()

# %% [markdown]
# VERIFICAMOS

# %%
scaled_features = scaler.transform(X)
X = pd.DataFrame(scaled_features,columns=data.columns[1:])
X.head(10)
# Out:
#    volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -0.521580     0.939332       -1.365027  -0.466421
# 1         -0.292593     1.941813       -1.365027   0.050060
# 2         -0.292593     1.273492       -1.161568  -0.171289
# 3          1.653789    -1.399789        1.483400  -0.466421
# 4         -0.521580     0.939332       -1.365027  -0.466421
# 5         -0.521580     0.716559       -1.365027  -0.540205
# 6         -0.235347     0.382399       -1.059838  -0.687771
# 7         -0.578826     0.660865       -1.365027  -0.982903
# 8         -0.292593     0.271012       -1.263297  -0.392638
# 9         -0.922306     0.271012       -0.958109  -0.540205
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0            -0.231395             -0.450466 -0.363601  0.555850   1.270695
# 1             0.234246              0.916307  0.643498  0.036167  -0.708927
# 2             0.107253             -0.059960  0.246762  0.140091  -0.325775
# 3            -0.252560              0.135294  0.429871  0.659805  -0.964362
# 4            -0.231395             -0.450466 -0.363601  0.555850   1.270695
# 5            -0.252560             -0.255213 -0.180492  0.555850   1.270695
# 6            -0.379554             -0.059960  0.399353 -0.171712  -0.070340
# 7            -0.464216             -0.059960 -0.760338 -1.107153   0.504390
# 8            -0.294891             -0.645720 -0.851892  0.036167   0.312812
# 9             0.213081             -0.059960  0.582462 -0.431569  -0.198057
#
#     alcohol   quality        Id  alcohol_bins
# 0 -0.573658 -0.963382 -1.735618     -0.966826
# 1  0.130881 -0.593601 -1.733462     -0.966826
# 2 -0.045254 -0.593601 -1.731306     -0.966826
# 3 -0.456235 -0.593601 -1.729150     -0.966826
# 4 -0.573658 -0.963382 -1.726993     -0.966826
# 5 -0.573658 -0.963382 -1.724837     -0.966826
# 6 -1.160774 -0.963382 -1.722681     -0.966826
# 7 -1.102062 -0.408711 -1.720525     -0.966826
# 8 -0.514946 -0.870937 -1.718369     -0.966826
# 9 -0.691081 -1.148272 -1.714057     -0.966826
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['volatile acidity'].plot(kind='hist', bins=20, title='volatile acidity')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['citric acid'].plot(kind='hist', bins=20, title='citric acid')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['residual sugar'].plot(kind='hist', bins=20, title='residual sugar')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['chlorides'].plot(kind='hist', bins=20, title='chlorides')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='volatile acidity', y='citric acid', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='citric acid', y='residual sugar', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='residual sugar', y='chlorides', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='chlorides', y='free sulfur dioxide', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Id']
#   ys = series['volatile acidity']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('Id', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Id')
# _ = plt.ylabel('volatile acidity')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Id']
#   ys = series['citric acid']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('Id', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Id')
# _ = plt.ylabel('citric acid')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Id']
#   ys = series['residual sugar']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('Id', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Id')
# _ = plt.ylabel('residual sugar')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Id']
#   ys = series['chlorides']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('Id', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Id')
# _ = plt.ylabel('chlorides')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['volatile acidity'].plot(kind='line', figsize=(8, 4), title='volatile acidity')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['citric acid'].plot(kind='line', figsize=(8, 4), title='citric acid')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['residual sugar'].plot(kind='line', figsize=(8, 4), title='residual sugar')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['chlorides'].plot(kind='line', figsize=(8, 4), title='chlorides')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.20, random_state=0)

# %%
# Entrenamiento del modelo
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
print(model.score(X_train , y_train))
print(model.score(X_test, y_test))
# Out:
# 1.0
# 0.8517241379310345

# %%
# Calcular la matriz de confusión

y_pred = model.predict(X_test)

confusion = confusion_matrix(y_test, y_pred)
print("Matriz de Confusión:")
print(confusion)


# Calcular la precisión del clasificador
accuracy = accuracy_score(y_test, y_pred)
print("Precisión del Clasificador:", accuracy)
# Out:
# Matriz de Confusión:
# [[ 99   0   0   0   0   0]
#  [  0  79   0   0   0   0]
#  [  0   3  60  27   7   2]
#  [  0   3  23  63  12   2]
#  [  0   1   4   2 101   0]
#  [  0   0   0   0   0  92]]
# Precisión del Clasificador: 0.8517241379310345

# %% [markdown]
# PRIMERA EJECUCION
#
# Splits: al menos 100 asignaciones, la mediana de la confiabilidad
# Académico (primera ejecucion) 80(train)/20(test) – Investigación 50/50 (segunda
# ejecución)

# %%
accuracy_list=[]
for i in range(100):
  X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.20, random_state=0)
  model= DecisionTreeClassifier()
  model.fit(X_train , y_train)
  y_pred = model.predict(X_test)
  confusion = confusion_matrix(y_test, y_pred)
  print("Matriz de Confusión:")
  print(confusion)
  accuracy = accuracy_score(y_test, y_pred)
  print("Precisión del Clasificador:", accuracy)
  accuracy_list.append(accuracy)
  print("__________________________________________________")
print(accuracy_list)
print(np.mean(accuracy_list))
# Out:
# Matriz de Confusión:
# [[ 99   0   0   0   0   0]
#  [  0  79   0   0   0   0]
#  [  0   5  61  27   4   2]
#  [  0   2  20  65  14   2]
#  [  0   1   4   2 101   0]
#  [  0   0   0   0   0  92]]
# Precisión del Clasificador: 0.8568965517241379
# __________________________________________________
# Matriz de Confusión:
# [[ 99   0   0   0   0   0]
#  [  0  79   0   0   0   0]
#  [  0   4  59  28   6   2]
#  [  0   2  26  62  11   2]
#  [  0   1   4   2 101   0]
#  [  0   0   0   0   0  92]]
# Precisión del Clasificador: 0.8482758620689655
# __________________________________________________
# Matriz de Confusión:
# [[ 99   0   0   0   0   0]
#  [  0  79   0   0   0   0]
#  [  0   3  60  28   6   2]
#  [  0   3  20  65  13   2]
#  [  0   1   4   2 101   0]
#  [  0   0   0   0   0  92]]
# Precisión del Clasificador: 0.8551724137931035
# __________________________________________________
# Matriz de Confusión:
# [[ 99   0   0   0   0   0]
#  [  0  79   0   0   0   0]
#  [  0   3  59  30   4   3]
#  [  0   2  26  63  11   1]
#  [  0   1   5   2 100   0]
#  [  0   0   0   0   0  92]]
# Precisión del Clasificador: 0.8482758620689655
# __________________________________________________
# Matriz de Confusión:
# [[ 99   0   0   0   0   0]
#  [  0  79   0   0   0   0]
#  [  0   4  59  28   5   3]
#  [  0   3  24  67   8   1]
#  [  0   1   4   2 101   0]
#  [  0   0   0   0   0  92]]
# Precisión del Clasificador: 0.8568965517241379
# __________________________________________________
# Matriz de Confusión:
# [[ 99   0   0   0   0   0]
#  [  0  79   0   0   0   0]
#  [  0   4  60  27   6   2]
#  [  0   2  27  61  11   2]
#  [  0   1   5   2 100   0]
#  [  0   0   0   0   0  92]]
# Precisión del Clasificador: 0.846551724137931
# __________________________________________________
# Matriz de Confusión:
# [[ 99   0   0   0   0   0]
#  [  0  79   0   0   0   0]
#  [  0   3  56  32   6   2]
#  [  0   3  27  62   9   2]
#  [  0   1   5   2 100   0]
#  [  0   0   0   0   0  92]]
# Precisión del Clasificador: 0.8413793103448276
# __________________________________________________
# Matriz de Confusión:
# [[ 99   0   0   0   0   0]
#  [  0  79   0   0   0   0]
#  [  0   4  59  29   4   3]
#  [  0   3  26  63  10   1]
#  [  0   1   4   2 101   0]
#  [  0   0   0   0   0  92]]
# Precisión del Clasificador: 0.85
# __________________________________________________
# Matriz de Confusión:
# [[ 99   0   0   0   0   0]
#  [  0  79   0   0   0   0]
#  [  0   5
379, 0.8551724137931035, 0.8517241379310345, 0.85, 0.8482758620689655, 0.8517241379310345, 0.8568965517241379, 0.8586206896551725, 0.85, 0.85, 0.853448275862069, 0.8517241379310345, 0.8551724137931035, 0.8586206896551725, 0.8586206896551725, 0.853448275862069, 0.8603448275862069, 0.85, 0.853448275862069, 0.853448275862069, 0.8517241379310345, 0.8482758620689655, 0.85, 0.853448275862069, 0.85, 0.8551724137931035, 0.8568965517241379]
# 0.8511206896551723

# %% [markdown]
# SEGUNDA EJECUCION

# %%
accuracy_list=[]
for i in range(100):
  X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.50, random_state=0)
  model= DecisionTreeClassifier()
  model.fit(X_train , y_train)
  y_pred = model.predict(X_test)
  confusion = confusion_matrix(y_test, y_pred)
  print("Matriz de Confusión:")
  print(confusion)
  accuracy = accuracy_score(y_test, y_pred)
  print("Precisión del Clasificador:", accuracy)
  accuracy_list.append(accuracy)
  print("__________________________________________________")
print(accuracy_list)
print(np.mean(accuracy_list))
# Out:
# Matriz de Confusión:
# [[230   0   0   0   0   0]
#  [  0 234   0   0   0   0]
#  [  0  18 156  56  16   0]
#  [  0  14  66 112  48   6]
#  [  0   0   7  20 206   7]
#  [  0   0   0   0   0 253]]
# Precisión del Clasificador: 0.8219461697722568
# __________________________________________________
# Matriz de Confusión:
# [[230   0   0   0   0   0]
#  [  0 234   0   0   0   0]
#  [  0  15 165  52  14   0]
#  [  0  18  68 113  41   6]
#  [  0   0   7  21 207   5]
#  [  0   0   0   0   0 253]]
# Precisión del Clasificador: 0.8295376121463078
# __________________________________________________
# Matriz de Confusión:
# [[230   0   0   0   0   0]
#  [  0 234   0   0   0   0]
#  [  1  17 165  47  16   0]
#  [  2  17  61 113  47   6]
#  [  0   0   4  17 214   5]
#  [  0   0   0   0   0 253]]
# Precisión del Clasificador: 0.8343685300207039
# __________________________________________________
# Matriz de Confusión:
# [[230   0   0   0   0   0]
#  [  0 234   0   0   0   0]
#  [  0  17 156  54  19   0]
#  [  0  14  74 111  43   4]
#  [  0   0   8  14 211   7]
#  [  0   0   0   0   0 253]]
# Precisión del Clasificador: 0.8247066942719117
# __________________________________________________
# Matriz de Confusión:
# [[230   0   0   0   0   0]
#  [  0 234   0   0   0   0]
#  [  1  18 159  54  14   0]
#  [  2  18  66 112  42   6]
#  [  0   0   8  17 210   5]
#  [  0   0   0   0   0 253]]
# Precisión del Clasificador: 0.8267770876466529
# __________________________________________________
# Matriz de Confusión:
# [[230   0   0   0   0   0]
#  [  0 234   0   0   0   0]
#  [  1  18 155  55  17   0]
#  [  2  18  64 109  48   5]
#  [  0   0   5  24 206   5]
#  [  0   0   0   0   0 253]]
# Precisión del Clasificador: 0.8191856452726018
# __________________________________________________
# Matriz de Confusión:
# [[230   0   0   0   0   0]
#  [  0 234   0   0   0   0]
#  [  0  16 162  56  12   0]
#  [  0  15  68 111  46   6]
#  [  0   0   6  15 214   5]
#  [  0   0   0   0   0 253]]
# Precisión del Clasificador: 0.8309178743961353
# __________________________________________________
# Matriz de Confusión:
# [[230   0   0   0   0   0]
#  [  0 234   0   0   0   0]
#  [  1  17 165  51  12   0]
#  [  2  18  66 112  44   4]
#  [  0   0   5  22 206   7]
#  [  0   0   0   0   0 253]]
# Precisión del Clasificador: 0.8281573498964804
# __________________________________________________
# Matriz de Confusión:
# [[230   0   0   0   0   0]
#  [  0 234   0   0   0   0]
#  [  1  18 157  56  14   0]
#  [  2  15  67 113  44   5]
#  [  0   0   2  13 220   5]
#  [  0   0   0   0   0 253]]
# Precisión del Clasificador: 0.8329882677708764
# __________________________________________________
# Matriz de Confusión:
# [[230   0   0   0   0   0]
#  [  0 234   0   0   0   0]
#  [  1  17 165  53  10   0]
#  [  2  19  67 106  45   7]
#  [  0   0   5  17 213   5]
#  [  0   0   0   0   0 253]]
# Precisión del Clasificador: 0.828847481021394
# __________________________________________________
# Matriz de Confusión:
# [[230   0   0   0   0   0]
#  [  0 234   0   0   0   0]
#  [  1  17 160  56  12   0]
#  [  2  18  70 111  38   7]
#  [  0   0   5  21 209   5]
#  [  0   0   0   0   0 253]]
# Precisión del Clasificador: 0.8260869565217391
# __________________________________________________
# Matriz de Confusión:
# [[230   0   0   0   0   0]
#  [  0 234   0   0   0   0]
#  [  0  18 160  52  16   0]
#  [  0  21  70 108  43   4]
#  [  0   0   7  16 210   7]
#  [  0   0   0   0   0 253]]
# Precisión del Clasificador: 0.8247066942719117
# __________________________________________________
# Matriz de Confusión:
# [[230   0   0   0   0   0]
#  [  0 234   0   0   0   0]
#  [  1  13 161  51  20   0]
#  [  2  15  71 107  47   4]
#  [  0   0   7  19 207   7]
#  [  0   0   0   0   0 253]]
# Precisión del Clasificador: 0.8226363008971704
# __________________________________________________
# Matriz de Confusión:
# [[230   0   0   0   0   0]
#  [  0 234   0   0   0   0]
#  [  0  15 156  60  15   0]
#  [  0  17  64 113  46   6]
#  [  0   0   2  21 210   7]
#  [  0   0   0   0   0 253]]
# Precisión del Clasificador: 0.8253968253968254
# __________________________________________________
# Matriz de Confusión:
# [[230   0   0   0   0   0]
#  [  0 234   0   0   0   0]
#  [  0  17 156  60  13   0]
#  [  0  19  67 115  39   6]
#  [  0   0   4  22 209   5]
#  [  0   0   0   0   0 253]]
# Precisión del Clasificador: 0.8260869565217391
# __________________________________________________
# Matriz de Confusión:
# [[230   0   0   0   0   0]
#  [  0 234   0   0   0   0]
#  [  1  17 157  55  16   0]
#  [  2  16  65 107  50   6]
#  [  0   0   4  19 212   5]
#  [  0   0   0   0   0 253]]
# Precisión del Clasificador: 0.8233264320220842
# __________________________________________________
# Matriz de Confusión:
# [[230   0   0   0   0   0]
#  [  0 234   0   0   0   0]
#  [  0  16 156  57  17   0]
#  [  0  18  71 103  48   6]
#  [  0   0   9  13 213   5]
#  [  0   0   0   0   0 253]]
# Precisión del Clasificador: 0.8205659075224293
# __________________________________________________
# Matriz de Confusión:
# [[230   0   0   0   0   0]
#  [  0 234   0   0   0   0]
#  [  1  15 154  59  17   0]
#  [  2  14  67 116  41   6]
#  [  0   0   8  21 204   7]
#  [  0   0   0   0   0 253]]
# Precisión del Clasificador: 0.8219461697722568
# __________________________________________________
# Matriz de Confusión:
# [[230   0   0   0   0   0]
#  [  0 234   0   0   0   0]
#  [  0  18 160  56  12   0]
#  [  0  15  62 119  46   4]
#  [  0   0   4  16 213   7]
#  [  0   0   0   0   0 253]]
# Precisión del Clasificador: 0.8343685300207039
# __________________________________________________
# Matriz de Confusión:
# [[230   0   0   0   0   0]
#  [  0 234   0   0   0   0]
#  [  1  18 161  54  12   0]
#  [  2  12  62 115  51   4]
#  [  0   0   8  22 203   7]
#  [  0   0   0   0   0 253]]
# Precisión del Clasificador: 0.8253968253968254
# __________________________________________________
# Matriz de Confusión:
# [[230   0   0   0   0   0]
#  [  0 234   0   0   0   0]
#  [  0  16 162  51  17   0]
#  [  0  20  59 117  46   4]
#  [  0   0   4  20 209   7]
#  [  0   0   0   0   0 253]]
# Precisión del Clasificador: 0.831608005521049
# __________________________________________________
# Matriz de Confusión:
# [[230   0   0   0   0   0]
#  [  0 234   0   0   0   0]
#  [  0  20 157  53  16   0]
#  [  0  14  65 117  45   5]
#  [  0   0   7  21 207   5]
#  [  0   0   0   0   0 253]]
# Precisión del Clasificador: 0.8267770876466529
# __________________________________________________
# Matriz de Confusión:
# [[230   0   0   0   0   0]
#  [  0 234   0   0   0   0]
#  [  1  16 165  45  19   0]
#  [  2  16  66 104  52   6]
#  [  0   0   7  12 214   7]
#  [  0   0   0   0   0 253]]
# Precisión del Clasificador: 0.8281573498964804
# __________________________________________________
# Matriz de Confusión:
# [[230   0   0   0   0   0]
#  [  0 234   0   0   0   0]
#  [  1  17